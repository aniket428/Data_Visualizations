# %%
import pandas as pd

# %%
import pandas as pd

# Load the main datasets
customers = pd.read_csv("AWCustomers.csv")
sales = pd.read_csv("AWSales.csv")
test_class = pd.read_csv("AWTest-Classification.csv")

# Check which one contains 'BikeBuyer'
print("Customers columns:", customers.columns.tolist())
print("Sales columns:", sales.columns.tolist())
print("Test Classification columns:", test_class.columns.tolist())
# Out:
# Customers columns: ['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix', 'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName', 'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate', 'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag', 'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome', 'LastUpdated']
# Sales columns: ['CustomerID', 'BikeBuyer', 'AvgMonthSpend']
# Test Classification columns: ['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix', 'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName', 'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate', 'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag', 'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome', 'LastUpdated']
